# %% [markdown]
# # RAG Pipeline Demo for SAQ
#
# Демонстрация работы RAG (Retrieval-Augmented Generation) для SAQ задач.
#
# Показывает:
# 1. Загрузку индекса Wikipedia
# 2. Поиск релевантных документов по вопросу
# 3. Формирование промпта с контекстом

# %%
import os                                                                                                                                                                                                                         
os.environ['LD_LIBRARY_PATH'] = '/software/genoa/r24.04/bzip2/1.0.8-GCCcore-12.3.0/lib:' + os.environ.get('LD_LIBRARY_PATH', '')

# %%
import sys
sys.path.insert(0, '../src')

from pathlib import Path
from qa_model.rag import WikipediaIndex, BM25Retriever
from qa_model.prompts import build_saq_prompt, SAQ_SYSTEM_PROMPT, SAQ_RAG_SYSTEM_PROMPT
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       2 sys.path.insert(0, '../src')
#       4 from pathlib import Path
# ----> 5 from qa_model.rag import WikipediaIndex, BM25Retriever
#       6 from qa_model.prompts import build_saq_prompt, SAQ_SYSTEM_PROMPT, SAQ_RAG_SYSTEM_PROMPT
#
# File /home/h5/albu670g/qa-model/notebooks/../src/qa_model/__init__.py:3
#       1 """QA Model - LoRA fine-tuning for MCQ and SAQ tasks."""
# ----> 3 from . import data
#       4 from . import models
#       5 from . import training
#
# File /home/h5/albu670g/qa-model/notebooks/../src/qa_model/data/__init__.py:3
#       1 """Data loading and preprocessing module."""
# ----> 3 from .preprocessing import load_mcq_data, load_saq_data, split_dataset
#       4 from .dataset import MCQDataset, SAQDataset
#       6 __all__ = [
#       7     "load_mcq_data",
#       8     "load_saq_data",
#    (...)     11     "SAQDataset",
#      12 ]
#
# File /home/h5/albu670g/qa-model/notebooks/../src/qa_model/data/preprocessing.py:7
#       4 from typing import Dict, List, Tuple
#       6 import pandas as pd
# ----> 7 from datasets import Dataset
#      10 def load_mcq_data(path: str) -> pd.DataFrame:
#      11     """Load MCQ dataset from CSV.
#      12
#      13     Args:
#    (...)     17         DataFrame with columns: MCQID, prompt, answer_idx
#      18     """
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "4.5.0"
# ---> 17 from .arrow_dataset import Column, Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/arrow_dataset.py:77
#      74 from tqdm.contrib.concurrent import thread_map
#      76 from . import config
# ---> 77 from .arrow_reader import ArrowReader
#      78 from .arrow_writer import ArrowWriter, OptimizedTypedSequence
#      79 from .data_files import sanitize_patterns
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/arrow_reader.py:30
#      27 import pyarrow.parquet as pq
#      28 from tqdm.contrib.concurrent import thread_map
# ---> 30 from .download.download_config import DownloadConfig  # noqa: F401
#      31 from .naming import _split_re, filenames_for_dataset_split
#      32 from .table import InMemoryTable, MemoryMappedTable, Table, concat_tables
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/download/__init__.py:9
#       1 __all__ = [
#       2     "DownloadConfig",
#       3     "DownloadManager",
#       4     "DownloadMode",
#       5     "StreamingDownloadManager",
#       6 ]
#       8 from .download_config import DownloadConfig
# ----> 9 from .download_manager import DownloadManager, DownloadMode
#      10 from .streaming_download_manager import StreamingDownloadManager
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/download/download_manager.py:32
#      30 from .. import config
#      31 from ..utils import tqdm as hf_tqdm
# ---> 32 from ..utils.file_utils import (
#      33     ArchiveIterable,
#      34     FilesIterable,
#      35     cached_path,
#      36     is_relative_path,
#      37     stack_multiprocessing_download_progress_bars,
#      38     url_or_path_join,
#      39 )
#      40 from ..utils.info_utils import get_size_checksum_dict
#      41 from ..utils.logging import get_logger, tqdm
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/utils/file_utils.py:44
#      42 from . import _tqdm, logging
#      43 from ._filelock import FileLock
# ---> 44 from .extract import ExtractManager
#      45 from .track import TrackedIterableFromGenerator
#      48 try:
#
# File /home/h5/albu670g/qa-model/.venv/lib/python3.11/site-packages/datasets/utils/extract.py:1
# ----> 1 import bz2
#       2 import gzip
#       3 import lzma
#
# File /software/genoa/r24.04/Python/3.11.3-GCCcore-12.3.0/lib/python3.11/bz2.py:17
#      14 import os
#      15 import _compression
# ---> 17 from _bz2 import BZ2Compressor, BZ2Decompressor
#      20 _MODE_CLOSED   = 0
#      21 _MODE_READ     = 1
#
# ImportError: libbz2.so.1.0: cannot open shared object file: No such file or directory

# %% [markdown]
# ## 1. Загрузка индекса Wikipedia

# %%
# Путь к индексу (измените на свой)
INDEX_DIR = Path("/data/cat/ws/albu670g-qa-model/rag/wiki_index")

print(f"Loading index from: {INDEX_DIR}")
index = WikipediaIndex.load(INDEX_DIR)
print(f"Loaded {len(index):,} documents")

# %%
# Создаём retriever
retriever = BM25Retriever(index=index, cache_enabled=False)

# Параметры RAG
TOP_K = 3
MAX_CONTEXT_TOKENS = 512

# %% [markdown]
# ## 2. Тестовые вопросы

# %%
# 5 примеров вопросов для SAQ
QUESTIONS = [
    "Who invented the telephone?",
    "What is the capital of France?",
    "When did World War II end?",
    "What is the chemical symbol for gold?",
    "Who wrote Romeo and Juliet?",
]

# %% [markdown]
# ## 3. Демонстрация поиска и формирования промптов
#
# Для каждого вопроса:
# 1. Выполняем BM25 поиск
# 2. Форматируем контекст
# 3. Строим финальный промпт

# %%
def demo_rag_pipeline(question: str, retriever: BM25Retriever, top_k: int = 3, max_tokens: int = 512):
    """Демонстрация RAG pipeline для одного вопроса."""
    print("=" * 80)
    print(f"ВОПРОС: {question}")
    print("=" * 80)
    
    # 1. Поиск релевантных документов
    print(f"\n[1] BM25 поиск (top_k={top_k})...")
    documents = retriever.retrieve(question, top_k=top_k)
    
    print(f"\nНайдено {len(documents)} документов:")
    for i, doc in enumerate(documents, 1):
        title = doc.get('title', 'N/A')
        text_preview = doc.get('text', '')[:200] + "..."
        print(f"\n  [{i}] {title}")
        print(f"      {text_preview}")
    
    # 2. Форматирование контекста
    print(f"\n[2] Форматирование контекста (max_tokens={max_tokens})...")
    context = retriever.format_context(documents, max_tokens=max_tokens)
    
    print(f"\nКОНТЕКСТ ({len(context)} символов):")
    print("-" * 40)
    print(context)
    print("-" * 40)
    
    return context

# %%
# Демо для всех вопросов
contexts = {}
for q in QUESTIONS:
    contexts[q] = demo_rag_pipeline(q, retriever, top_k=TOP_K, max_tokens=MAX_CONTEXT_TOKENS)
    print("\n")

# %% [markdown]
# ## 4. Полные промпты с RAG контекстом
#
# Показываем финальные промпты, которые отправляются в модель.

# %%
# Загружаем tokenizer для форматирования промптов
from transformers import AutoTokenizer

# Используем LLaMA-3 tokenizer (или замените на свой)
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
print(f"Tokenizer loaded: {MODEL_ID}")

# %%
def show_full_prompt(question: str, context: str, tokenizer):
    """Показать полный промпт с RAG контекстом."""
    print("=" * 80)
    print(f"ВОПРОС: {question}")
    print("=" * 80)
    
    # Промпт БЕЗ RAG
    prompt_no_rag = build_saq_prompt(tokenizer, question, context=None)
    
    # Промпт С RAG
    prompt_with_rag = build_saq_prompt(tokenizer, question, context=context)
    
    print("\n[БЕЗ RAG]")
    print("-" * 40)
    print(prompt_no_rag)
    print(f"\nТокенов: {len(tokenizer.encode(prompt_no_rag))}")
    
    print("\n[С RAG]")
    print("-" * 40)
    print(prompt_with_rag)
    print(f"\nТокенов: {len(tokenizer.encode(prompt_with_rag))}")
    
    return prompt_with_rag

# %%
# Показать промпты для всех вопросов
for q in QUESTIONS:
    show_full_prompt(q, contexts[q], tokenizer)
    print("\n\n")

# %% [markdown]
# ## 5. Сравнение System Prompts

# %%
print("SAQ_SYSTEM_PROMPT (без RAG):")
print("-" * 40)
print(SAQ_SYSTEM_PROMPT)
print("\n")
print("SAQ_RAG_SYSTEM_PROMPT (с RAG):")
print("-" * 40)
print(SAQ_RAG_SYSTEM_PROMPT)

# %% [markdown]
# ## 6. Интерактивный тест
#
# Введите свой вопрос для проверки RAG pipeline.

# %%
# Введите свой вопрос
custom_question = "What is the speed of light?"

# Поиск и контекст
custom_context = demo_rag_pipeline(custom_question, retriever, top_k=TOP_K, max_tokens=MAX_CONTEXT_TOKENS)

# Полный промпт
print("\n")
show_full_prompt(custom_question, custom_context, tokenizer)

# %% [markdown]
# ## 7. Статистика индекса

# %%
import os

print("Статистика индекса:")
print(f"  - Документов: {len(index):,}")

# Размеры файлов
docs_file = INDEX_DIR / "documents.json"
bm25_file = INDEX_DIR / "bm25_index.pkl"

if docs_file.exists():
    size_mb = docs_file.stat().st_size / (1024 * 1024)
    print(f"  - documents.json: {size_mb:.1f} MB")

if bm25_file.exists():
    size_mb = bm25_file.stat().st_size / (1024 * 1024)
    print(f"  - bm25_index.pkl: {size_mb:.1f} MB")

# Пример документа
print("\nПример документа из индекса:")
sample_doc = index.documents[0]
print(f"  Title: {sample_doc.get('title', 'N/A')}")
print(f"  Text: {sample_doc.get('text', '')[:300]}...")
