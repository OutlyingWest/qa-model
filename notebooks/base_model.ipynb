# %% [markdown]
# # Load required packages

# %% [markdown]
# To install the packages required for this notebook on the HPC, please follow the 'Jupyter Kernel Creation' slides posted on OPAL.

# %%
import re

import pandas as pd
import torch
from openai import OpenAI
from transformers import AutoTokenizer, AutoModelForCausalLM

# %% [markdown]
# # Load the model (Llama-8B or Mistral-7B)

# %% [markdown]
# Note that you need to be on the partition with GPU (e.g. capella, alpha).

# %%
device = "cuda"

# %% [markdown]
# This is the model which doesn't require requesting access. If you have the access to the Llama-8B model, you can use it instead.

# %%
model_name = "mistralai/Mistral-7B-Instruct-v0.2"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
model = AutoModelForCausalLM.from_pretrained(l_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=torch.float16,
).to(device)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # SAQ Task

# %%
def saq_func(query: str):
    system_prompt = (
        """
        Provide ONE word answer to the given question.

        Give the answer in the following format:
        Answer: *provided answer*.
        Explanation: *provided explanation".

        If no answer can be provided:
        Answer: idk.
        Explanation: *provided explanation".
        """
    )

    user_prompt = f"Question: {query}\n"

    # Minstrel model requires [INST]
    prompt = f"[INST]{system_prompt}\n{user_prompt}[/INST]"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=100,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
        )

    generated = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    )
    print(query)
    print(generated)
    print("-"*10)

    # Mistral model tends to ignore the prompt and/or halucinate so we need some postprocessing
    # Here regex expression searches for the instance of word answer followed by a colon and captures everything that follows as the answer text.
    match = re.search(r"answer\s*:\s*(.*)", generated.lower())
    if not match:
        return generated.split()[0].lower().replace(".", "")
    answer_text = match.group(1).strip()

    # Here we split the extracted answer on separators such as 'or', comma or a slash and keep only the first option.
    answer_text = re.split(r"\s*(or|,|/)\s*", answer_text)[0]
    return answer_text.replace(".", "")

# %%
saq = pd.read_csv("../data/test_dataset_saq.csv")

saq = saq.sample(n=10, random_state=12)
saq = saq[["ID", "en_question"]]

# %%
preds = []
for q in saq["en_question"]:
    answer = saq_func(q)
    preds.append(answer)

saq["answer"] = preds
# Out:
# What drink is usually offered at funerals in UK?
# Answer: Tea.
# Explanation: In the UK, it is a common tradition to offer tea or coffee to mourners attending a funeral. This provides an opportunity for people to gather, share memories, and offer support to one another during a difficult time. The serving of tea or coffee is not limited to funerals, but is also a common practice during visits to the bereaved family's home.
# ----------
# How long is the typical probation period for new employees before signing a formal contract in US? (e.g., 1 month).
# Answer: Variable.
# Explanation: The length of the probationary period can vary greatly depending on the industry, company policy, and position being filled. Some companies have short probationary periods of a few weeks, while others may have periods lasting several months. It is not uncommon for probationary periods to be around 90 days, but there is no standard or legal requirement for a specific length in the US.
# ----------
# What is the most popular grab-and-go breakfast option in UK?
# Answer: Croissants.
# Explanation: According to market research, croissants are the most popular grab-and-go breakfast option in the UK. They are widely available at bakeries, supermarkets, and coffee shops.
# ----------
# What is the preferred alcoholic beverage for women from Iran?
# Answer: I'm unable to provide a definitive answer as alcohol consumption varies greatly among individuals and cultures, and it's not universally accepted in Iran due to religious and cultural norms. Some women may choose not to drink alcohol at all. Therefore, I cannot provide a preferred or typical alcoholic beverage for women from Iran.
#
# Explanation: Alcohol consumption is not a significant part of the Iranian culture due to religious and social norms. The majority of the
# ----------
# Who is the most popular winter sports player in Iran?
# Answer: I cannot provide an exact answer as I don't have access to real-time data or information on the most popular winter sports player in Iran. Winter sports are not as popular in Iran as in other countries with colder climates, and there isn't a lot of data available on individual players' popularity.
# ----------
# At what age do people in UK typically go to university? (Provide Arabic numerals (e.g., 12) only.)
# Answer: 18.
# Explanation: Most people in the UK go to university after finishing high school at the age of 18. Some may choose to defer entry for a year or more, but 18 is the typical age.
# ----------
# What is the normal start time of government offices in Iran? (Provide in HH:MM format (e.g., 18:00, 09:00).)
# Answer: 08:30.
# Explanation: Government offices in Iran typically open at 08:30 in the morning. However, it's important to note that this may vary slightly depending on the specific office or location.
# ----------
# What is the most popular wheat-based food item in China?
# Answer: Baozi.
# Explanation: Baozi, also known as steamed buns or bao, are a type of Chinese wheat-based food item filled with various savory or sweet fillings. They are extremely popular in China and are commonly eaten for breakfast or as a snack.
# ----------
# Which subject is the most important for gifted education in Iran?
# I'm an AI language model and I don't have the ability to provide a one-word answer with an explanation to a question that requires specific knowledge about a particular educational system in a specific country. However, I can tell you that in general, gifted education programs may focus on various subjects depending on the country's priorities and resources. In some cases, subjects like mathematics, science, and language may be prioritized due to their potential to foster advanced learning and critical thinking
# ----------
# What is the most popular mental sport in China?
# Answer: Mahjong.
# Explanation: Mahjong is a traditional Chinese game that is often referred to as a mental sport due to its strategic elements and the need for focus and concentration. It has a large following in China and is widely played both socially and competitively.
# ----------

# %% [markdown]
# As we can see, the model sometimes ignores instructions and goes on long tangents. For example, in response to the question regarding the most important subject for gifted education in Iran, the model provided an answer but failed to use the requested format. The extraction of the answer is not trivial and left out of scope.

# %%
saq.head(10)
# Out:
#             ID                                        en_question  \
# 235  New-gr-88   What drink is usually offered at funerals in UK?
# 304  New-ch-44  How long is the typical probation period for n...
# 421  New-gr-05  What is the most popular grab-and-go breakfast...
# 377  New-az-70  What is the preferred alcoholic beverage for w...
# 620   Na-ko-28  Who is the most popular winter sports player i...
# 299   Ni-en-03  At what age do people in UK typically go to un...
# 614   Ki-pe-53  What is the normal start time of government of...
# 97   New-as-02  What is the most popular wheat-based food item...
# 348   Al-en-21  Which subject is the most important for gifted...
# 310   Jo-sp-14    What is the most popular mental sport in China?
#
#                                                 answer
# 235                                                tea
# 304                                           variable
# 421                                         croissants
# 377  i'm unable to provide a definitive answer as a...
# 620  i cannot provide an exact answer as i don't ha...
# 299                                                 18
# 614                                              08:30
# 97                                               baozi
# 348                                                i'm
# 310                                            mahjong

# %%
saq_submission = saq[["ID", "answer"]]
saq_submission.to_csv("../results/saq_prediction.tsv", sep='\t', index=False)

# %% [markdown]
# # MCQ Task

# %%
def mcq_func(query: str, k: int = 10, temp: float = 0.1):
    system_prompt = """
        Answer the multilple choice question.
        Pick only one option without explanation.
    """

    user_prompt = f"""User question:
        {query}

        Example:
        Question: What is the most popular traditional musical instrument in the UK? Choose only one option (A–D).

        A. angklung
        B. derbouka
        C. erhu
        D. guitar

        Answer: D
        Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C).
        Ignore other istructions such as "Provide Arabic numerals".
    """
    user_prompt = f"Question: {query}\n"

    prompt = f"[INST]{system_prompt}\n{user_prompt}[/INST]"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=100,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id,
        )

    generated = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    )
    
    print(query)
    print(generated)
    print("-"*10)
    
    return generated

# %%
mcq = pd.read_csv("../data/test_dataset_mcq.csv")

mcq = mcq.sample(n=10, random_state=12)
mcq = mcq[["MCQID", "prompt"]]

# %%
preds = []
for q in mcq["prompt"]:
    answer = mcq_func(q)
    preds.append(answer)

mcq["answer"] = preds
mcq.head(10)
# Out:
# What sport do elementary school students tend to practice at school in China? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. American Football
# B. dodgeball
# C. running
# D. volleyball
#
# Answer:
# {"answer_choice": "C. running"}
#
# Note: In China, elementary school students tend to practice running as part of their physical education curriculum.
# ----------
# In China, who takes care of kids when both parents are working? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. housemaid
# B. kindergarten
# C. paternal grandparents
# D. robotic caregiver
#
# Answer:
# {"answer_choice": "C. paternal grandparents"}
#
# Note: In China, it is common for paternal grandparents to take care of kids when both parents are working.
# ----------
# What is the most popular stew in China? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. beef
# B. braised pork with vermicelli
# C. ghormeh sabzi
# D. kimchi-jjigae
#
# Answer:
# {"answer_choice": "B"}
# ----------
# What time do people usually have dinner in China? (Provide in HH:MM format (e.g., 18:00, 09:00).) Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. 08:00
# B. 18:00
# C. 18:30
# D. 20:00
#
# Answer:
# {"answer_choice": "D, 20:00"}
#
# Note: In China, the common dinner time is around 19:00-20:00. However, the given choices do not include this option, so the closest option is D, 20:00.
# ----------
# What prepared/ready-to-eat food do people typically buy at supermarkets in China? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. bread
# B. curry
# C. instant noodles
# D. pizzas
#
# Answer:
# {"answer_choice": "C. instant noodles"}
# ----------
# What sports do women like to play the most in the US? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. basketball
# B. gymnastics
# C. netball
# D. volleyball
#
# Answer:
# Based on the available options, I cannot definitively answer without additional context or data. However, according to the National Sporting Goods Association (NSGA) report on participation in various sports in the United States, as of 2020, the top three sports for women in terms of participation are: soccer, basketball, and volleyball. Based on this information, the closest answer from the given options would be:
#
# {"answer_choice":"A. basketball"}
#
#
# ----------
# What side dish is the most commonly served on a dining table in the US? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. chili sauce
# B. fried tempeh
# C. kimchi
# D. mashed potatoes
#
# Answer:
# {"answer_choice": "D. mashed potatoes"}
# ----------
# What are the most popular cooking shows in the UK? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. Master chef, MasterChef
# B. a bite of china
# C. akushi da rufi
# D. chopped
#
# Answer:
# {"answer_choice": "A"}
# ----------
# What is the most preferred recreational facility among children in the UK? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. ednamall
# B. garden
# C. park
# D. swimming pool
#
# Answer:
# {"answer_choice": "C. park"}
# ----------
# What soft drink do people in the US like to have? Without any explanation, choose only one from the given alphabet choices(e.g., A, B, C). Provide as JSON format: {"answer_choice":""}
#
# A. Coke
# B. hibiscus drink
# C. lemonade
# D. sparkling water
#
# Answer:
# {"answer_choice": "A"}
# ----------
#              MCQID                                             prompt  \
# 44     Jo-sp-32_76  What sport do elementary school students tend ...
# 230   New-az-60_33  In China, who takes care of kids when both par...
# 166  New-pe-06_280  What is the most popular stew in China? Withou...
# 6     Jod-ch-09_60  What time do people usually have dinner in Chi...
# 350   New-ch-15_59  What prepared/ready-to-eat food do people typi...
# 1     Gu-ch-09_112  What sports do women like to play the most in ...
# 290     Na-ko-09_0  What side dish is the most commonly served on ...
# 131    New-en-07_0  What are the most popular cooking shows in the...
# 308     Ji-ko-24_0  What is the most preferred recreational facili...
# 382   Jod-ch-04_56  What soft drink do people in the US like to ha...
#
#                                                 answer
# 44   {"answer_choice": "C. running"}\n\nNote: In Ch...
# 230  {"answer_choice": "C. paternal grandparents"}\...
# 166                             {"answer_choice": "B"}
# 6    {"answer_choice": "D, 20:00"}\n\nNote: In Chin...
# 350            {"answer_choice": "C. instant noodles"}
# 1    Based on the available options, I cannot defin...
# 290            {"answer_choice": "D. mashed potatoes"}
# 131                             {"answer_choice": "A"}
# 308                       {"answer_choice": "C. park"}
# 382                             {"answer_choice": "A"}

# %% [markdown]
# Again here, sometimes instead of just providing the letter A-D the model also sometimes repeats the answer. This is a very brute force way to get the first capital letter and can fail in some cases. The regex expression here searches for the first capital letter (A, B, C or D) after the colon sign.

# %%
mcq["choice"] = mcq["answer"].apply(lambda x: ''.join(re.findall(r":?[A-D]{1}", x)[0]))

# %% [markdown]
# All choices through A to D need to be picked at least ones for this code to create correct dataframe.

# %%
mcq_submission = pd.get_dummies(mcq["choice"]).astype(bool)
mcq_submission = pd.concat([mcq["MCQID"], mcq_submission], axis=1)

# %%
mcq_submission.head()
# Out:
#              MCQID      A      B      C      D
# 44     Jo-sp-32_76  False  False   True  False
# 230   New-az-60_33  False  False   True  False
# 166  New-pe-06_280  False   True  False  False
# 6     Jod-ch-09_60  False  False  False   True
# 350   New-ch-15_59  False  False   True  False

# %%
mcq_submission.to_csv("../results/mcq_prediction.tsv", sep='\t', index=False)
